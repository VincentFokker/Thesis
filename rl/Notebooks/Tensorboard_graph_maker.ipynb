# %%
from rl.helpers import Load_data, plotly_data, matplot_data
#Test Function
environment = 'AbstractConveyor'
subdir = '20201123_0044'
# Out:
# INFO:tensorflow:TensorFlow

# %%
scalar = 'episode_reward'
timevar = 'step' # wall_time or step
reward = Load_data(environment, subdir, scalar=scalar)
figure = matplot_data(reward, scalar, timevar=timevar)
# Out:
# start import 0 / 5 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 5 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 5 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 5 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 5 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done

# %%
figure.savefig('test.png')

# %%
scalar = 'loss/loss'
timevar = 'step' # wall_time or steps
loss = Load_data(environment, subdir, scalar=scalar)
matplot_data(loss, scalar, timevar=timevar)
# Out:
# start import 0 / 5 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 5 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 5 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 5 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 5 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
